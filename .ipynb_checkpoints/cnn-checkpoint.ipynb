# %% [markdown]
# # Bat Orientaion Calls - Classification with CNN

# %% [markdown]
# ## General Preparations
#
# Getting started with tensorflow on Mac M1:
# https://github.com/jeffheaton/t81_558_deep_learning/blob/master/install/tensorflow-install-mac-metal-jul-2021.ipynb
#
# activate environment
# `conda activate apple_tensorflow`
#
# deactivate  environment
# `conda deactivate`
#
# start jupyter
# `jupyter notebook`

# %%
from matplotlib import image
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import sklearn as sk
import seaborn as sns
from sklearn.metrics import confusion_matrix
import pathlib
import shutil
import os
import sys
import tensorflow as tf
import itertools

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
import keras_tuner as kt

# %%
print(f"Tensor Flow Version: {tf.__version__}")
print(f"Keras Version: {tf.keras.__version__}")
print(f"Keras Tuner Version: {kt.__version__}")
print(f"Python {sys.version}")
print(f"Pandas {pd.__version__}")
print(f"Scikit-Learn {sk.__version__}")
gpu = len(tf.config.list_physical_devices('GPU'))>0
print("GPU is", "available" if gpu else "NOT AVAILABLE")
# Out:
# Tensor Flow Version: 2.9.2
# Keras Version: 2.9.0
# Keras Tuner Version: 1.1.2
# Python 3.9.13 | packaged by conda-forge | (main, May 27 2022, 17:00:33)
# [Clang 13.0.1 ]
# Pandas 1.4.2
# Scikit-Learn 1.1.1
# GPU is available

# %% [markdown]
# We have to reanrage the given data to a new folder structure to use `image_dataset_from_directory`:
#
# - images
#    - class1
#         - *.png
#    - class2
#         - *.png
#    ...

# %%
df = pd.read_csv("LMU_20180326_class.csv", header=0, delimiter=';')

shutil.unpack_archive("LMU_20180326_png.zip", "")

for index, row in df.iterrows():
    folder = row['Species']
    filename = row['Filename'].replace('.jpg', '.png')
    
    if not os.path.exists(f'LMU_20180326_png_sorted/{folder}'):
        os.makedirs(f'LMU_20180326_png_sorted/{folder}')
    
    shutil.copy2(f'LMU_20180326_png/{filename}', f'LMU_20180326_png_sorted/{folder}/{filename}')

# %% [markdown]
# ## Global Functions for Plots

# %%
def plot_confusion_matrix(cm, classes):
    fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(20,10), sharex=True, sharey=True)
    
    ax1.title.set_text('Absolut')
    ax2.title.set_text('Relative')
    fig.text(0.5, 0, 'Predicated Label', ha='center')
    fig.text(0, 0.5, 'True label', va='center', rotation='vertical')

    cmn = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
      
    sns.heatmap(cm, annot=True, xticklabels=classes, yticklabels=classes, ax=ax1, cmap="YlGnBu")
    sns.heatmap(cmn, annot=True, fmt='.2f', xticklabels=classes, yticklabels=classes, ax=ax2, cmap="YlGnBu")
    
    plt.tight_layout()
    plt.show()

# %%
def plot_model_loss_acc(epochs_range, acc, val_acc, loss, val_loss):
    plt.figure(figsize=(15, 10))
    plt.subplot(1, 2, 1)
    plt.plot(epochs_range, acc, label='Training Accuracy', marker='o')
    plt.plot(epochs_range, val_acc, label='Validation Accuracy', marker='o')
    plt.legend(loc='lower right')
    plt.title('Training and Validation Accuracy')

    plt.subplot(1, 2, 2)
    plt.plot(epochs_range, loss, label='Training Loss', marker='o')
    plt.plot(epochs_range, val_loss, label='Validation Loss', marker='o')
    plt.legend(loc='upper right')
    plt.title('Training and Validation Loss')
    plt.show()

# %% [markdown]
# ## Data Preparation

# %%
data_dir = pathlib.Path("LMU_20180326_png_sorted")
image_count = len(list(data_dir.glob('*/*.png')))
print(f"Found {image_count} images")
# Out:
# Found 1089 images

# %%
df = pd.read_csv("LMU_20180326_class.csv", header=0, delimiter=';')
species = df['Species'].unique()
print(f"{len(species)} different species: {species}")
# Out:
# 9 different species: ['Bartfledermaus' 'Fransenfledermaus' 'Mausohr' 'Wasserfledermaus'
#  'Fledermaus nicht bestimmbar' 'Schwarzbild' 'Langohrfledermaus'
#  'Bechsteinfledermaus' 'Große Hufeisennase']

# %%
bat_filename = df["Filename"][0]
bat_species = df["Species"][0]
bat_image = image.imread(f'LMU_20180326_png_sorted/{bat_species}/{bat_filename.replace(".jpg", ".png")}')
img_height, img_width, img_channels = bat_image.shape
batch_size = 64
print(f"Bat image shape: {bat_image.shape}")
# Out:
# Bat image shape: (288, 432, 4)

# %% [markdown]
# Create training and validation data sets with keras `image_dataset_from_directory`. We are using 80% for training and 20% for validation.

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="training",
  label_mode='categorical',
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)

val_ds = tf.keras.utils.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="validation",
  label_mode='categorical',
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 1089 files belonging to 9 classes.
# Using 872 files for training.
# Found 1089 files belonging to 9 classes.
# Using 217 files for validation.

# %% [markdown]
# We can access the different `class_names` of the data set:

# %%
class_names = train_ds.class_names
print(class_names)
# Out:
# ['Bartfledermaus', 'Bechsteinfledermaus', 'Fledermaus nicht bestimmbar', 'Fransenfledermaus', 'Große Hufeisennase', 'Langohrfledermaus', 'Mausohr', 'Schwarzbild', 'Wasserfledermaus']

# %% [markdown]
# ## Overview

# %% [markdown]
# ### Plot

# %%
plt.figure(figsize=(15, 15))
for images, labels in train_ds.take(1):

  for i in range(9):
    index = tf.argmax(labels[i], axis=0)
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[index.numpy()])
    plt.axis("off")

# %% [markdown]
# ### Input shape

# %%
for image_batch, labels_batch in train_ds:
  print(image_batch.shape)
  print(labels_batch.shape)
  break
# Out:
# (64, 288, 432, 3)
# (64, 9)

# %% [markdown]
# ## Models

# %% [markdown]
# ### Preparations

# %% [markdown]
# Configure the dataset for performance, see: https://www.tensorflow.org/tutorials/images/classification#configure_the_dataset_for_performance

# %%
AUTOTUNE = tf.data.AUTOTUNE

train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# The RGB channel values are in the [0, 255] range.
# Here, we will standardize values to be in the [0, 1] range by using tf.keras.layers.Rescaling:

# %%
normalization_layer = tf.keras.layers.Rescaling(1./255)

# %% [markdown]
# An example:
# (Later we will use the Rescaling directly in our model.)

# %%
normalized_ds = train_ds.map(lambda x, y: (normalization_layer(x), y))
image_batch, labels_batch = next(iter(normalized_ds))
first_image = image_batch[0]
print(np.min(first_image), np.max(first_image))
# Out:
# 0.0 1.0

# %% [markdown]
# ### First Simple Model

# %%
model = keras.Sequential([
  layers.Rescaling(1./255, input_shape=(img_height, img_width, 3)),
  layers.Conv2D(32,                      
                  kernel_size=(3,3),         
                  strides=(1,1),            
                  padding='same',            
                  activation='relu'),
  layers.MaxPooling2D(),
    
  layers.Conv2D(64,                      
                  kernel_size=(3,3),         
                  strides=(1,1),            
                  padding='same',            
                  activation='relu'),
  layers.MaxPooling2D(),
    
  layers.Conv2D(128,                      
                  kernel_size=(3,3),         
                  strides=(1,1),            
                  padding='same',            
                  activation='relu'),
  layers.MaxPooling2D(),
  
  layers.Flatten(),
  layers.Dropout(0.05),
  layers.Dense(160, activation='relu'),
  layers.Dense(len(class_names), activation='softmax')
])

# %%
adamOptimizer=keras.optimizers.Adam(learning_rate=0.0001, beta_1=0.9, beta_2=0.999, amsgrad=False)


model.compile(optimizer=adamOptimizer,
      loss='categorical_crossentropy',
      metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling_1 (Rescaling)     (None, 288, 432, 3)       0
#
#  conv2d (Conv2D)             (None, 288, 432, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 144, 216, 32)     0
#  )
#
#  conv2d_1 (Conv2D)           (None, 144, 216, 64)      18496
#
#  max_pooling2d_1 (MaxPooling  (None, 72, 108, 64)      0
#  2D)
#
#  conv2d_2 (Conv2D)           (None,
# 14/14 [==============================] - 9s 678ms/step - loss: 0.0248 - accuracy: 1.0000 - val_loss: 1.5649 - val_accuracy: 0.7419
# Epoch 36/40
# 14/14 [==============================] - 9s 675ms/step - loss: 0.0211 - accuracy: 1.0000 - val_loss: 1.7073 - val_accuracy: 0.7419
# Epoch 37/40
# 14/14 [==============================] - 10s 691ms/step - loss: 0.0198 - accuracy: 1.0000 - val_loss: 1.6078 - val_accuracy: 0.7143
# Epoch 38/40
# 14/14 [==============================] - 10s 720ms/step - loss: 0.0175 - accuracy: 1.0000 - val_loss: 1.6582 - val_accuracy: 0.7419
# Epoch 39/40
# 14/14 [==============================] - 9s 676ms/step - loss: 0.0139 - accuracy: 1.0000 - val_loss: 1.7038 - val_accuracy: 0.7512
# Epoch 40/40
# 14/14 [==============================] - 9s 670ms/step - loss: 0.0141 - accuracy: 1.0000 - val_loss: 1.7559 - val_accuracy: 0.7419

# %%
model.evaluate(val_ds)
# Out:
# 4/4 [==============================] - 1s 200ms/step - loss: 1.7559 - accuracy: 0.7419
# [1.7558833360671997, 0.7419354915618896]

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plot_model_loss_acc(epochs_range=range(epochs), acc=acc, val_acc=val_acc, loss=loss, val_loss=val_loss)

# %%
y_pred = model.predict(val_ds)
y_true = np.concatenate([y for x, y in val_ds], axis=0)

cm = confusion_matrix(y_true=np.argmax(y_true, axis=-1), y_pred=np.argmax(y_pred, axis=-1))
    
plot_confusion_matrix(cm=cm, classes=class_names)
# Out:
# 4/4 [==============================] - 1s 410ms/step

# %% [markdown]
# ### Enhancement with Data Augmentation

# %%
with tf.device('/cpu:0'):
    data_augmentation = keras.Sequential(
      [
        layers.RandomFlip("horizontal",
                          input_shape=(img_height,
                                      img_width,
                                      3)),
        layers.RandomRotation(0.2),
        layers.RandomZoom(0.2),
      ]
    )

model_da = keras.Sequential([
  data_augmentation,
  layers.Rescaling(1./255),
  layers.Conv2D(30,                      
                  kernel_size=(3,3),         
                  strides=(1,1),            
                  padding='same',            
                  activation='relu'),
  layers.MaxPooling2D(),
    
  layers.Conv2D(60,                      
                  kernel_size=(3,3),         
                  strides=(1,1),            
                  padding='same',            
                  activation='relu'),
  layers.MaxPooling2D(),
    
  layers.Conv2D(90,                      
                  kernel_size=(3,3),         
                  strides=(1,1),            
                  padding='same',            
                  activation='relu'),
  layers.MaxPooling2D(),
  
  layers.Flatten(),
  layers.Dropout(0.05),
  layers.Dense(160, activation='relu'),
  layers.Dense(len(class_names), activation='softmax')
])

# %%
adamOptimizer = adamOptimizer=keras.optimizers.Adam(learning_rate=0.0001, beta_1=0.9, beta_2=0.999, amsgrad=False)
model_da.compile(optimizer=adamOptimizer,
      loss='categorical_crossentropy',
      metrics=['accuracy'])

# %%
model_da.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential_1 (Sequential)   (None, 288, 432, 3)       0
#
#  rescaling_2 (Rescaling)     (None, 288, 432, 3)       0
#
#  conv2d_3 (Conv2D)           (None, 288, 432, 30)      840
#
#  max_pooling2d_3 (MaxPooling  (None, 144, 216, 30)     0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 144, 216, 60)      16260
#
#  max_pooling2d_4 (MaxPooling  (None, 72, 108, 60)      0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 72, 108, 90)       48690
#
#  max_pooling2d_5 (MaxPooling  (None, 36, 54, 90)       0
#  2D)
#
#  flatten_1 (Flatten)         (None, 174960)            0
#
#  dropout_1 (Dropout)         (None, 174960)            0
#
#  dense_2 (Dense)             (None, 160)               27993760
#
#  dense_3 (Dense)             (None, 9)                 1449
#
# =================================================================
# Total params: 28,060,999
# Trainable params: 28,060,999
# Non-trainable params: 0
# _________________________________________________________________

# %%
epochs=40
history_da = model_da.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/40
# 14/14 [==============================] - 22s 1s/step - loss: 1.4379 - accuracy: 0.4920 - val_loss: 1.4613 - val_accuracy: 0.5207
# Epoch 2/40
# 14/14 [==============================] - 23s 2s/step - loss: 1.4406 - accuracy: 0.5161 - val_loss: 1.3454 - val_accuracy: 0.5161
# Epoch 3/40
# 14/14 [==============================] - 24s 2s/step - loss: 1.3753 - accuracy: 0.5229 - val_loss: 1.4437 - val_accuracy: 0.5207
# Epoch 4/40
# 14/14 [==============================] - 23s 2s/step - loss: 1.3589 - accuracy: 0.5505 - val_loss: 1.3185 - val_accuracy: 0.5945
# Epoch 5/40
# 14/14 [==============================] - 25s 2s/step - loss: 1.3385 - accuracy: 0.5321 - val_loss: 1.2733 - val_accuracy: 0.5484
# Epoch 6/40
# 14/14 [==============================] - 22s 2s/step - loss: 1.2668 - accuracy: 0.5677 - val_loss: 1.2871 - val_accuracy: 0.5346
# Epoch 7/40
# 14/14 [==============================] - 21s 2s/step - loss: 1.2780 - accuracy: 0.5860 - val_loss: 1.3663 - val_accuracy: 0.5438
# Epoch 8/40
# 14/14 [==============================] - 22s 2s/step - loss: 1.2262 - accuracy: 0.5711 - val_loss: 1.4074 - val_accuracy: 0.5806
# Epoch 9/40
# 14/14 [==============================] - 22s 2s/step - loss: 1.1970 - accuracy: 0.6044 - val_loss: 1.2220 - val_accuracy: 0.6221
# Epoch 10/40
# 14/14 [==============================] - 20s 1s/step - loss: 1.1759 - accuracy: 0.6032 - val_loss: 1.5987 - val_accuracy: 0.4194
# Epoch 11/40
# 14/14 [==============================] - 21s 2s/step - loss: 1.2037 - accuracy: 0.5883 - val_loss: 1.2530 - val_accuracy: 0.5806
# Epoch 12/40
# 14/14 [==============================] - 23s 2s/step - loss: 1.1631 - accuracy: 0.6147 - val_loss: 1.2262 - val_accuracy: 0.6175
# Epoch 13/40
# 14/14 [==============================] - 22s 2s/step - loss: 1.1062 - accuracy: 0.6330 - val_loss: 1.2830 - val_accuracy: 0.5622
# Epoch 14/40
# 14/14 [==============================] - 20s 1s/step - loss: 1.1125 - accuracy: 0.6216 - val_loss: 1.3860 - val_accuracy: 0.5346
# Epoch 15/40
# 14/14 [==============================] - 21s 2s/step - loss: 1.1291 - accuracy: 0.6284 - val_loss: 1.4134 - val_accuracy: 0.5207
# Epoch 16/40
# 14/14 [==============================] - 20s 1s/step - loss: 1.1488 - accuracy: 0.6193 - val_loss: 1.3043 - val_accuracy: 0.5991
# Epoch 17/40
# 14/14 [==============================] - 21s 1s/step - loss: 1.0985 - accuracy: 0.6422 - val_loss: 1.2438 - val_accuracy: 0.6313
# Epoch 37/40
# 14/14 [==============================] - 20s 1s/step - loss: 0.8808 - accuracy: 0.6766 - val_loss: 1.3840 - val_accuracy: 0.4977
# Epoch 38/40
# 14/14 [==============================] - 21s 1s/step - loss: 0.8722 - accuracy: 0.7064 - val_loss: 1.1663 - val_accuracy: 0.6820
# Epoch 39/40
# 14/14 [==============================] - 21s 1s/step - loss: 0.9151 - accuracy: 0.6789 - val_loss: 1.1964 - val_accuracy: 0.6636
# Epoch 40/40
# 14/14 [==============================] - 21s 1s/step - loss: 0.9026 - accuracy: 0.6881 - val_loss: 1.2255 - val_accuracy: 0.7235

# %%
model_da.evaluate(val_ds)
# Out:
# 4/4 [==============================] - 1s 179ms/step - loss: 1.2255 - accuracy: 0.7235
# [1.2254598140716553, 0.7235022783279419]

# %%
acc = history_da.history['accuracy']
val_acc = history_da.history['val_accuracy']

loss = history_da.history['loss']
val_loss = history_da.history['val_loss']

epochs_range = range(epochs)

plot_model_loss_acc(epochs_range=range(epochs), acc=acc, val_acc=val_acc, loss=loss, val_loss=val_loss)

# %%
y_pred = model_da.predict(val_ds)
y_true = np.concatenate([y for x, y in val_ds], axis=0)

cm = confusion_matrix(y_true=np.argmax(y_true, axis=-1), y_pred=np.argmax(y_pred, axis=-1))
    
plot_confusion_matrix(cm=cm, classes=class_names)
# Out:
# 4/4 [==============================] - 1s 239ms/step

# %% [markdown]
# ## Keras Parameter Tuning

# %%
def model_builder(hp):
  model = keras.Sequential([
      layers.Rescaling(1./255, input_shape=(img_height, img_width, 3)),
      layers.Conv2D(32,                      
                      kernel_size=(3,3),         
                      strides=(1,1),            
                      padding='same',            
                      activation='relu'),
      layers.MaxPooling2D(),

      layers.Conv2D(64,                      
                      kernel_size=(3,3),         
                      strides=(1,1),            
                      padding='same',            
                      activation='relu'),
      layers.MaxPooling2D(),

      layers.Conv2D(128,                      
                      kernel_size=(3,3),         
                      strides=(1,1),            
                      padding='same',            
                      activation='relu'),
      layers.MaxPooling2D(),

      layers.Flatten(),
      layers.Dropout(0.05),
  ])
  
  # Tune the number of units in the first Dense layer
  # Choose an optimal value between 32-512
  hp_units = hp.Int('units', min_value=32, max_value=512, step=32)
  model.add(keras.layers.Dense(units=hp_units, activation='relu'))
  model.add(keras.layers.Dense(len(class_names), activation='softmax'))

  # Tune the learning rate for the optimizer
  # Choose an optimal value from 0.01, 0.001, or 0.0001
  hp_learning_rate = hp.Choice('learning_rate', values=[1e-2, 1e-3, 1e-4])

  model.compile(optimizer=keras.optimizers.Adam(learning_rate=hp_learning_rate),
                loss='categorical_crossentropy',
                metrics=['accuracy'])

  return model

# %%
tuner = kt.Hyperband(model_builder,
                     objective='val_accuracy',
                     max_epochs=20,
                     factor=3,
                     directory='my_dir',
                     project_name='bats_opti')

# %%
stop_early = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5)

# %%
tuner.search(x=train_ds, epochs=50, validation_data=val_ds, callbacks=[stop_early])
# Out:
# Trial 30 Complete [00h 03m 30s]
# val_accuracy: 0.774193525314331
#
# Best val_accuracy So Far: 0.7834101319313049
# Total elapsed time: 00h 42m 52s
# INFO:tensorflow:Oracle triggered exit

# %% [markdown]
# Get the optimal hyperparameters

# %%
best_hps=tuner.get_best_hyperparameters(num_trials=1)[0]

print(f"""
The hyperparameter search is complete. The optimal number of units in the first densely-connected
layer is {best_hps.get('units')} and the optimal learning rate for the optimizer
is {best_hps.get('learning_rate')}.
""")
# Out:
# The hyperparameter search is complete. The optimal number of units in the first densely-connected
# layer is 160 and the optimal learning rate for the optimizer
# is 0.0001.

# %% [markdown]
# Build the model with the optimal hyperparameters and train it on the data for 50 epochs

# %%
model = tuner.hypermodel.build(best_hps)
history = model.fit(x=train_ds, validation_data=val_ds, epochs=50)

val_acc_per_epoch = history.history['val_accuracy']
best_epoch = val_acc_per_epoch.index(max(val_acc_per_epoch)) + 1
print('Best epoch: %d' % (best_epoch,))
# Out:
# Epoch 1/50
# 2022-06-15 20:09:56.860151: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 14/14 [==============================] - ETA: 0s - loss: 1.8917 - accuracy: 0.3830
# 2022-06-15 20:10:07.546438: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 14/14 [==============================] - 13s 821ms/step - loss: 1.8917 - accuracy: 0.3830 - val_loss: 1.6384 - val_accuracy: 0.4378
# Epoch 2/50
# 14/14 [==============================] - 11s 740ms/step - loss: 1.6051 - accuracy: 0.4759 - val_loss: 1.5898 - val_accuracy: 0.4332
# Epoch 3/50
# 14/14 [==============================] - 11s 761ms/step - loss: 1.5415 - accuracy: 0.4759 - val_loss: 1.5402 - val_accuracy: 0.4378
# Epoch 4/50
# 14/14 [==============================] - 10s 710ms/step - loss: 1.4980 - accuracy: 0.4828 - val_loss: 1.5466 - val_accuracy: 0.4608
# Epoch 5/50
# 14/14 [==============================] - 10s 733ms/step - loss: 1.4608 - accuracy: 0.4954 - val_loss: 1.4943 - val_accuracy: 0.4516
# Epoch 6/50
# 14/14 [==============================] - 10s 727ms/step - loss: 1.4089 - accuracy: 0.5126 - val_loss: 1.4700 - val_accuracy: 0.4608
# Epoch 7/50
# 14/14 [==============================] - 11s 741ms/step - loss: 1.3965 - accuracy: 0.5080 - val_loss: 1.4576 - val_accuracy: 0.5115
# Epoch 8/50
# 14/14 [==============================] - 10s 760ms/step - loss: 1.3258 - accuracy: 0.5298 - val_loss: 1.3660 - val_accuracy: 0.5530
# Epoch 9/50
# 14/14 [==============================] - 11s 775ms/step - loss: 1.2276 - accuracy: 0.6044 - val_loss: 1.3270 - val_accuracy: 0.5392
# Epoch 10/50
# 14/14 [==============================] - 11s 754ms/step - loss: 1.1412 - accuracy: 0.6319 - val_loss: 1.3026 - val_accuracy: 0.6037
# Epoch 11/50
# 14/14 [==============================] - 11s 767ms/step - loss: 1.0623 - accuracy: 0.6399 - val_loss: 1.2869 - val_accuracy: 0.5945
# Epoch 12/50
# 14/14 [==============================] - 12s 836ms/step - loss: 0.9790 - accuracy: 0.6835 - val_loss: 1.1177 - val_accuracy: 0.7005
# Epoch 13/50
# 14/14 [==============================] - 11s 814ms/step - loss: 0.8947 - accuracy: 0.7156 - val_loss: 1.1005 - val_accuracy: 0.6866
